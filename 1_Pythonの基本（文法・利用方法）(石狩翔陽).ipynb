# %% [markdown]
# # Pythonの使い方
# ここでは基本文法と環境設定について確認します。

# %% [markdown]
# ## 基本文法
# プログラミングの文法と基本的な流れについて確認します。
#
# Google colaboratoryを使った基本的なPythonの学習は次のサイトが参考になります。
#
# https://www.python.jp/

# %% [markdown]
# ### プログラムの書き方
# １行に１命令（１つの機能）のみ書くのが基本です。
#
# エラーは起きて「当たり前」あまり気にしないようにしましょう。

# %% [markdown]
# ### インデント
# Pythonでは「**インデント**」が重要な意味を持ちます。
#
# 同じインデントの文（命令の１行）は上から下へ解釈されて実行していきます。
#
# インデントが異なると特別な意味と解釈しますので、通常はエラー「**IndentationError: unexpected indent**」になります。

# %%
100 * 100
100 / 2
 50 + 2 #インデントエラーになります。

# から右側の部分はコメント（プログラムの説明を記述したもの）なので、実行には無関係となります。
# この行はコメントになります。

# %% [markdown]
# ### 基本は順次
#
# プログラムの基本処理は上から下へ順番に処理されます。

# %%
# プログラムの処理の順番 print()はprint関数と言われカッコ内の値を表示する機能があります。
print('画面出力１')
print('画面出力２')
print('画面出力３')

# 出力順は記載した通りの順番になります。

# %% [markdown]
# ## 変数の利用と結果の表示
# ### 変数を使って値を保存したり、処理の結果を取っておくことができます。
#
# ### 定義した変数は利用を終了したときに削除することもできます。
#
# 変数以外の値は**リテラル**と言われ、「Pythonのプログラムに直接記述された値」を指します。

# %%
x = 100 # x という箱に100を入れるという意味になります。
y = 50  # ここで100や50はリテラルと言われます。
z = x + y

r = 3.14
b = True

print(z)

print(x)

# xという変数を削除することもできます。
del x

# xが削除され未定義になるためエラーになります。
print(x)

# %% [markdown]
# ## Pythonの基本
#
# プログラムでは上から下に流れる記述以外に「分岐」や「繰り返し」という制御構文が使われます。
#
# 基本的にすべてのプログラムは順次・分岐（選択）・反復（繰り返し）で記載できることが証明されています。

# %% [markdown]
# ### 分岐（選択）
#
# #### 分岐（選択）では問題の意図を理解して条件判定式の意味を理解するが重要です。
# 書き方はインデントを理解してどこからどこまでが条件成立したときに実行されるブロックなのか考えて記載します。
#
# 選択（if-then-else）のプログラムの考え方は論理値（真理値）が重要になります。

# %% [markdown]
# ![flowchart.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ```
# if 電球がコンセントに接続している == False:
#     コンセントに接続する
#     プログラム終了
# if 電球が切れている == True:
#     電球を交換する
#     プログラム終了
# 電灯を修理する
#
# ```

# %% [markdown]
# ![flowchart.drawio (2).png](data:image/png;base64,...)

# %% [markdown]
# ```
# if 電球がコンセントに接続している == False:
#     コンセントに接続する
# elif 電球が切れている == True:
#     電球を交換する
# else:
#     電灯を修理する
#
# ```

# %%
# 真（成立）の値を表示
print(True)
print(10 > 1)

# 偽（不成立）の値を表示
print(10 < 1)

# 課題：変数aを用意して数値-10を入れましょう


# 変数aの値がマイナスであれば真となる条件式の値を表示しましょう
print(a < 0)

# 変数aの値がマイナスであれば'マイナス'と表示するプログラムを作りましょう
# ここで17行目が右側にインデント（字下げ）されています。この字下げがifによる条件が「真」の時に実行される範囲となります。
if a < 0 : #字下げの前にコロンが付きます
    print('マイナスです')

# 課題：変数aの値がプラスであれば「プラスです」を表示してみましょう

#if 条件:
#    print('マイナスです')
#else:
#    print('プラスです')

# %% [markdown]
# 下のプログラムはインデント（字下げ）でエラーが発生します
# 正しく動作するように修正しましょう。
#
# 100点満点でテストした結果をscoreという変数に格納します。
#
# テストの点数が80点以上で「A」、70点以上で「B」、60点以上で「C」、60点未満で「D」とします。
# ただし入力データのエラー処理は考えないこととします。

# %%
# 変数scoreに数値60を格納する
score = 60

if score >= 80:
# インデント（字下げ）がされていないとエラーになります
print("あなたはAです")
# インデント（字下げ）がおかしいとエラーになります
    elif score >= 70:
    print("あなたはBです")
elif score >= 60:
    print("あなたはCです")
else:
    print("あなたはDです")

# %% [markdown]
# 条件式に設定する式の意味を理解しましょう
# 割り切れる割り切れないは割った「あまり（演算子 %）」で判定することができます。
#
# キーボードから変数valueに入力した値を読み取り2,3,5,7,11という素数で割り切れるかどうかを判定します。

# %%
# 数値が入力された場合、対応する素数を表示してください。
#value = int(input("数値を入力してください："))

# 割り算の余りが0だと割り切れたことになります。
# 割ったあまりは%で計算することができます。
#if :
#    print("素数2で割り切れます")
#elif :
#    print("素数3で割り切れます")
#elif :
#    print("素数5で割り切れます")
#elif :
#    print("素数7で割り切れます")
#elif :
#    print("素数11で割り切れます")
#else:
#    print("素数2,3,5,7,11で割り切れない数値です")

# %% [markdown]
# ### 反復（繰り返し）
#
# #### 反復（繰り返し）はどれだけ同じような処理を全く同一の表現に書き換えることができれば効率よくプログラムをすることができます。
#
# 反復にはwhileとfor文が使えます。
#
# while文を使って条件が成立している間繰り返すことができます。

# %% [markdown]
# 変数cntの値が1～5まで値を表示しながら繰り返す文は次のように書けます。

# %%
cnt = 1
# 条件が成立していれば繰り返す
#
while cnt <= 5:
    print("1 cnt = ", cnt)
    # cntの値を１増する（インクリメント）
    cnt = cnt + 1

# %% [markdown]
# ![loop.drawio.png](data:image/png;base64,...)

# %% [markdown]
# 同様の記述をfor文を使って記述します。
#
# rangeは値の塊を作るイメージここでは1,2,3,4,5の値を作ります。
#
# rangeのカッコの中は整数で（初期値start,停止値stop,増分値step）停止値（stop）はstop - 1の値を最大値とし（増分値がマイナスの場合はstop + 1の値が最小値）ます。

# %%
for cnt in range(1,6):
    print("2 cnt = ", cnt)

# %% [markdown]
# 同様の値の塊を作るイメージはリスト「[ ]」やタプル「( )」とも言われます。
#
# リスト「[ ]」を使って同じ内容を記述します。

# %%
# []（角カッコ・大カッコ）で囲まれた値は「,」カンマで区切ることで複数の値を入れることができます。
# これをリストと言います。
for cnt in [1,2,3,4,5]:
    print("3 cnt = ", cnt)
# Out:
# 3 cnt =  1
# 3 cnt =  2
# 3 cnt =  3
# 3 cnt =  4
# 3 cnt =  5

# %% [markdown]
# タプル「( )」を使って同じ内容を記述します。

# %%
# ()(カッコ)で囲まれた値も「,」カンマで区切ることで複数の値を入れることができます。
for cnt in (1,2,3,4,5):
    print("4 cnt = ", cnt)

# %% [markdown]
# #### リストとタプルの違い（余裕があれば）
#
# リストはミュータブル（変更可能）なデータ型、タプルはイミュータブル（変更不可）なデータ型です。

# %%
l = [1,2,3,4]

l[1] = 99
print(l)

t = (1,2,3,4)
# エラーになります。
t[1] = 99
print(t)

# %% [markdown]
# #### 繰り返し表現を使う意味
#
# 繰り返し加算をすることを考えましょう。

# %%
sum = 1 + 2 + 3 + 4 + 5
print(sum)

# %% [markdown]
# 同じ表現への変更します。
#
# 同じような行が表現されていることを確認します。

# %%
sum = 0
sum = sum + 1
sum = sum + 2
sum = sum + 3
sum = sum + 4
sum = sum + 5
print(sum)

# %% [markdown]
# 増やす値（incv）を変化させるプログラムに変更してみます。
#
# 全く同じ行が繰り返されていることがポイントです。
#
# incv = incv + 1
#
# sum = sum + incv

# %%
# 　14行目から25行目
sum = 0
incv = 0

incv = incv + 1
sum = sum + incv
incv = incv + 1
sum = sum + incv
incv = incv + 1
sum = sum + incv
incv = incv + 1
sum = sum + incv
print(sum)

# %% [markdown]
# for文を使って5回繰り返すプログラムに変更します。
#
# 同じ表現であればプログラム中で繰り返すことが可能になります。

# %%
sum = 0
incv = 0
# for文で5回繰り返す range(5)は[0,1,2,3,4]と同じ意味を持ちます。
for times in range(5):
    incv = incv + 1
    sum = sum + incv
print(sum)

# %% [markdown]
# 1,3,5,7,9と奇数値のみ加算するプログラムに変更してみましょう　2行目と4行目を変更してみましょう。

# %%
sum = 0
incv = 0
for times in range(5):
    incv = incv + 1
    sum = sum + incv
print(sum)

# %% [markdown]
# 1,3,5,7,9と奇数値のみ加算するプログラムを変数incvを使わないように変更してみましょう。
#
# rangeの引数を変更し、for文の変数を活用しましょう。

# %%
sum = 0
for incv in range(1,5):
    sum = sum + incv

print("合計 = ",sum)
# Out:
# 合計 =  10

# %% [markdown]
# ### 辞書
#
# 辞書を使って値を取り出します
# 辞書(dict)というデータ型があります。Pythonで使えるとても便利なデータ型なのでデータの活用方法として覚えておくとよいでしょう。

# %%
# {}（波カッコ・中カッコ）で囲み「キー:値」の形式を「,」カンマで区切ることで複数の値の組み合わせを入れることができます。
d = {
    'name':'nakayama' ,
    'age':19 ,
    'addr':'sapporo'
}
# 全体を出力します。
print(d)

# 名前「'name'」のみ取り出します。
print(d['name'])
# Out:
# {'name': 'nakayama', 'age': 19, 'addr': 'sapporo'}
# nakayama

# %% [markdown]
# 辞書の中身を反復を使って取り出してみましょう。

# %%
# {}（波カッコ・中カッコ）で囲み「キー:値」の形式を「,」カンマで区切ることで複数の値の組み合わせを入れることができます。
d = {
    'name':'nakayama' ,
    'age':19 ,
    'addr':'sapporo'
}
# 詳しい内容はここでは省略しますが、辞書の中身を取り出すためには「.items()」を使います。
for key,value in d.items():
    print(key, " = ", value)
# Out:
# name  =  nakayama
# age  =  19
# addr  =  sapporo

# %% [markdown]
# ## ライブラリの利用(機能拡張の方法)
# ### importの利用
#
# Pythonでは様々な機能がライブラリとして提供されています。
#
# これらの多くのライブラリを利用するためにはimportによる機能の取り込みが必要となります。

# %%
# 画像を描画するためのImageモジュールを利用してみましょう。

# イメージを作成する。'RGB'は赤・緑・青の色指定を意味する
# ここではエラーになります。
im = Image.new('RGB', (300, 300),( 0, 255, 0))

display(im)

# %%
# Pillowライブラリを利用する場合は名称PILを使う宣言が必要で、
# import文で描画に必要なライブラリを指定する。
from PIL import Image

# importされているとエラーになりません。
im = Image.new('RGB', (300, 300),( 0, 255, 0))

display(im)

# %% [markdown]
# 日本語のグラフを表示するために機能追加をする方法の一つに「japanize_matplotlib」の利用があります。

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
# 日本語matplotlibを設定

x = [ 1, 2, 3, 4, 5, 6 ]
data = [ 200, 220, 240, 220, 260, 210 ]
# データラベルに日本語を指定することもできます。
label = [ '西区','東区','南区','北区','豊平区','手稲区']
# フォントサイズを指定します。
plt.xticks(fontsize=14)
plt.bar( x, data ,tick_label = label)

plt.show()

# %% [markdown]
# ### importできないときには機能を追加インストールする
# 拡張機能を利用したい時はpipコマンドを使う
# コマンドを利用する場合は!(ビックリマーク)を付けて実行します。

# %%
# !pip install japanize_matplotlib

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
# 日本語matplotlibを設定

x = [ 1, 2, 3, 4, 5, 6 ]
data = [ 200, 220, 240, 220, 260, 210 ]
# データラベルに日本語を指定することもできます。
label = [ '西区','東区','南区','北区','豊平区','手稲区']
# フォントサイズを指定します。
plt.xticks(fontsize=14)
plt.bar( x, data ,tick_label = label)

plt.show()

# %% [markdown]
# ## Googleドライブを利用する
#
# ### Googleドライブを利用するにはドライブをマウントする必要があります。
#
# マウントしたドライブの中身を見るために「ls」という外部コマンドを呼び出します。

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls /content/drive/MyDrive

# %% [markdown]
# コマンドでフォルダーを作ることができます。
# シンプルに「!」をつけてmkdirコマンドを実行してみましょう。

# %%
# !mkdir img

# %% [markdown]
# 作成したフォルダーにコマンドでイメージをコピーする方法は次の通りとおなります。

# %%
# !cp /content/drive/MyDrive/image img
